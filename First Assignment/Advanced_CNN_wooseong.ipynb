# %% [markdown]
# <a href="https://colab.research.google.com/github/devahws/ai-security/blob/master/First%20Assignment/Advanced_CNN_wooseong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 신경망을 사용하는 기계학습 중 CNN은 이미지 프로세싱 등의 분야에서 좋은 성능을 발휘한다.
# CNN은 기본적으로 nxn 모양의 필터 모양을 가지고 이미지의 부분을 자른 후 특징을 뽑아낸다는 특징이 있다.
#
# Pytorch에서 제공하는 conv2d 함수는 data가 몇 겹의 데이터로 구성되어있는지를 나타내는 in_channel(cifar10과 같은 컬러 사진의 경우 RGB를 사용하기 때문에 in_channel이 3, MNIST와 같은 흑백 사진의 경우 1), 출력할 conv layer의 층을 결정하는 out_channel, 마지막으로 필터의 사이즈를 결정하는 kernal size를 입력받아 실행된다.
#
# ![대체 텍스트](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=http%3A%2F%2Fcfile3.uf.tistory.com%2Fimage%2F99EC1C435B48B8481B98EC)
#
# 위의 사진을 보면 가로와 세로가 각각 32이고, 깊이가 3인 이미지가 있고, 크기가 5x5인 3겹 필터를 사용하여 activation map을 만들고 있다.
# 이렇게 만들어진 activation map은 28x28개의 픽셀로 이뤄져있는데 각 픽셀의 갯수는 필터의 사이즈인 5x5x3= 75이다.
#
# 이렇게 하나의 이미지에 대해 activation map을 만든 후 Pooling이라는 연산을 사용하여 activation map의 의미있는 특징들을 추출한다.
#
# ![대체 텍스트](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=http%3A%2F%2Fcfile29.uf.tistory.com%2Fimage%2F991526445B49831101DC96)
#
# 위의 사진은 Max Pooling이라는 기법으로 activation map을 일정한 사이즈로 나눈 후 나눠진 영역에서 가장 큰 값을 대표값으로 설정하여 정해진 사이즈의 필터에 특징을 추출해낸다.
# Pooling의 방법으로는 해당 구역의 평균을 뽑아내는 average pooling과 최솟값을 뽑아내는 Min pooling등의 방법도 존재한다.
#
# ![대체 텍스트](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=http%3A%2F%2Fcfile21.uf.tistory.com%2Fimage%2F999AB9425B498822317983)
#
# 이런 방식으로 Conv layer를 생성하고 그 conv layer를 pooling layer를 만든 뒤, 다시 pooling layer에 대해 conv layer를 생성하고 그 결과를 pooling하는 것을 반복하여 마지막에 fully connect layer에서 특징들을 유의미하게 분류하는 과정을 거친다.
#
# ![대체 텍스트](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=http%3A%2F%2Fcfile29.uf.tistory.com%2Fimage%2F99E0713D5B498D4A1FF2D4)
#
# 이 과정을 Pytorch를 이용하여 구현하면 위의 사진과 같다.
#
# __init__ 함수의 fully connect layer에서는 neural network의 Linear함수를 통해 추출한 픽셀들을 0~9까지의 총 10개의 라벨에 따라 분류한다. 추출한 픽셀의 갯수는 수학적으로 계산하기보다는 아무 값이나 대입한 후 런타임 에러에서 말해주는 값으로 입력하면 된다.
#
# ![대체 텍스트](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=http%3A%2F%2Fcfile30.uf.tistory.com%2Fimage%2F992ABA455B45E74E18AD88)
#
# 그리고 forward 함수에서는 마지막에 fully requested layer까지 거친 특징 값들을 위와 같은 softmax 함수를 통해 사람이 인식하기 쉬운 분류 값으로 출력받는다.
#
# 위의 과정을 train 과정을 거쳐 test해보면 MNIST에 대한 인식의 정확도가 96% 정도에 이름을 알 수 있다.
#
# 이러한 CNN의 성능을 더욱 높일 수 있도록 고안한 것이 Advanced CNN이다.
# ![대체 텍스트](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=http%3A%2F%2Fcfile27.uf.tistory.com%2Fimage%2F999A7A3F5B49B62125233E)
#
# Advanced CNN에서는 하나의 이미지를 다양한 필터들로 conv layer를 만든 후에 그 layer들을 하나로 합친 다음 pooling layer를 만들어서 더욱 유의미한 특징 값을 추출하는 방식이다. 하나의 pooling layer를 만들 때 5x5, 3x3, 1x1 등의 다양한 커널 사이즈의 필터를 사용하기 때문에 conv layer를 만드는 과정에서 padding과 stride를 적절히 설정해줘야한다.
#
#
# Advanced CNN의 핵심은 바로 conv layer를 만드는 과정에서 1x1 필터를 사용한다는 점이다.
# ![대체 텍스트](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=http%3A%2F%2Fcfile5.uf.tistory.com%2Fimage%2F9933A3475B49C4F90A1CE7)
#
# 사진과 같이 커널 사이즈가 1인 필터를 사용하고 out_channel을 원래 이미지 in_chnnel의 절반인 32로 줄인 다음, 이 conv layer를 기반으로 다른 conv layer를 만들게 되면, 원래 이미지와 같은 width와 height의 이미지임에도 추후 conv layer를 만드는 연산의 양이 효과적으로 줄어들기 때문이다.
#
# 예를 들어, 28x28의 192체널로부터 5x5 conv layer 32체널을 만든다면 5x5x192x32의 파라미터가 만들어지겠지만,  1x1로 32체널로 줄인다면 줄이는 데에는 1x1x192x32의 파라미터가, conv layer엔 5x5x32x32의 파라미터가 필요하다.
#
# 즉, 기존에는 (5x5x28x28x192x32) 개의 연산이 필요 한 상황이라면 이제는 (1x1x28x28x192x32) + (28x28x5x5x32x32) 개의 연산이 필요하다.
#
# ![대체 텍스트](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=http%3A%2F%2Fcfile30.uf.tistory.com%2Fimage%2F997412365B49D6DD25877C)
#
# 이렇게 여러 개의 conv layer를 합쳐서 하나의 pooling layer로 바꾸는 과정을 Inception Module이라고 하는데, 이러한 inception module들을 이어붙이면 기존의 CNN보다 더 의미있는 특징 추출과 라벨 분류 학습이 가능하다는 게 Advanced CNN의 아이디어이다.
#
# Pytorch를 이용한 Advanced CNN의 구현을 아래 코드에서 설명해보겠다.

# %%
import torch 
import torch.nn as nn 
import torch.nn.functional as F 
import torch.optim as optim 
from torchvision import datasets, transforms
# 데이터를 원활하게 가져오고 변형하기 위해 torchvision을 import
# transforms는 선처리를 위한 함수


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') 
batch_size = 64
# deep learning에서 분석에 사용하는 데이터는 양이 너무 방대하기 때문에 전체 데이터를 한 번의 연산으로 돌리기에는 cpu의 무리가 따름
# 때문에 전체 데이터를 몇 번에 나눠서 연산할지 결정하는 batch_size 설정
# batch_size가 클수록 연산 속도가 오래 걸림

train_dataset = datasets.MNIST(root='./mnist_data/',train = True, transform = transforms.ToTensor(),download = True) 
test_dataset = datasets.MNIST(root='./mnist_data/',train = False, transform = transforms.ToTensor()) 
# google colab의 ./data 디렉토리에 MNIST의 train과 test 데이터 다운로드
# transform 함수를 통해 다운받은 데이터를 Tensor형태로 저장함

train_loader = torch.utils.data.DataLoader(dataset=train_dataset,batch_size=batch_size,shuffle=True) 
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,batch_size=batch_size,shuffle=False)
# DataLoader에 train_dataset과 test_dataset을 가져와서 각각 train_loader와 test_loader를 설정
# batch_size는 위에서 설정한 64의 값을 그대로 가져옴
# shuffle은 데이터 순서를 shuffle은 데이터 순서를 무작위로 섞을 것인지 결정
# shuffle값이 True면 순서를 무작위로, False면 순서대로 배치

class InceptionModule(nn.Module):
# class가 곧 생성할 Neural network
# class의 이름이 네트워크의 이름
# InceptionModule이란 하나의 이미지를 다양한 사이즈의 필터를 사용해서 특징을 추출한 conv layer들을 하나로 합쳐 max pooling하는 하나의 싸이클


                                                    # 초기화 함수
   def __init__(self,in_channels):
      super(InceptionModule,self).__init__()
      # super()에 생성할 네트워크를 저장

      self.branch1x1 = nn.Conv2d(in_channels,16,kernel_size=1) 
      # 1. in_channel의 경우 사진 데이터를 통해 입력받음
      # 2. out_channel의 수, 즉 뽑아낼 conv layer들을 16겹으로 출력
      # 3. kernel_size가 1이므로 사용할 필터의 크기가 1x1
      # 1x1 필터로 먼저 conv layer를 생성한 후 이 conv layer에 대하여 연산을 진행하면 1x1 필터를 사용하지 않을 때보다 연산을 효과적으로 줄일 수 있음

      self.branch5x5_1 = nn.Conv2d(in_channels,16,kernel_size=1) 
      self.branch5x5_2 = nn.Conv2d(16,24,kernel_size=5,padding=2)
      # 1. branch1x1과 같이 크기가 1x1인 필터를 사용하여 원래 이미지에 대한 conv layer 생성
      # 2. 1x1로 출력한 conv layer를 5x5 필터를 사용하고 24겹의 out_channel로 출력.  
      # 3. out_channels의 크기가 같아야 마지막에 모든 conv layer들을 합쳐서 사용할 수 있음. 때문에 out_channel의 사이즈를 같게 하기 위해 패딩 추가

      self.branch3x3_1 = nn.Conv2d(in_channels,16,kernel_size=1) 
      self.branch3x3_2 = nn.Conv2d(16,24,kernel_size=3,padding=1) 
      self.branch3x3_3 = nn.Conv2d(24,24,kernel_size=3,padding=1)
      # 위의 branch5x5와 같이 out_channel의 사이즈를 동일하게 conv layer 출력

      self.branch_pool = nn.Conv2d(in_channels,24,kernel_size=1) 
      # average pool 이후에 1x1 필터를 사용하는 conv_layer 출력

                                                    # forward 함수 생성
   def forward(self,x):
      branch1x1 = self.branch1x1(x)
      # __init__함수에서 초기화했던 self.branch1x1에 x를 대입하여 branch1x1에 저장

      branch5x5 = self.branch5x5_1(x) 
      branch5x5 = self.branch5x5_2(branch5x5)
      # __init__함수에서 초기화했던 self.branch5x5_1()에 x를 대입한 값을 branch5x5에 저장
      # self.branch5x5_1(x)의 출력값을 다시 self.branch5x5_2에 대입하여 brach5x5에 저장

      branch3x3 = self.branch3x3_1(x) 
      branch3x3 = self.branch3x3_2(branch3x3) 
      branch3x3 = self.branch3x3_3(branch3x3)
      # brach5x5와 같은 방법으로 conv2d 과정을 모두 거친 self.branch3x3_3(branch3x3)의 값을 branch3x3에 저장

      branch_pool = F.avg_pool2d(x,kernel_size=3,stride=1,padding=1)
      branch_pool = self.branch_pool(branch_pool) 
      # 입력 이미지에 대하여 3x3 필터를 이용하고 stride=1, padding=1을 설정하여 average_pool2d를 연산한 값을 branch_pool에 저장
      # brach_pool에 저장된 값을 __init__에서 정의한 self.branch_pool()에 대입하여 branch_pool에 저장

      outputs = [branch1x1,branch5x5,branch3x3,branch_pool]
      # 위의 연산에서 구한 1x1, 5x5, 3x3, brach_pool의 conv layer들을 outputs에 하나로 통합(concatenate)
      return torch.cat(outputs,1)

                          # MainNet 설정
                          # MainNet에서 앞서 설정한 Inception module들을 연결해주는 역할을 함
class MainNet(nn.Module):
     def __init__(self): 
       super(MainNet,self).__init__() 
       self.conv1 = nn.Conv2d(1,10,kernel_size=5)
        # MNIST는 흑백 사진이기 때문에 in_channel은 1, out_channel을 10으로, 필터의 크기는 5x5로 설정
       self.conv2 = nn.Conv2d(88,20,kernel_size=5) 
        # self.conv2는 conv1에서 연산한 결과를 입력으로 받음
        # Inception Module의 forward 함수에서 도출한 outputs의 크기가 88이기 때문에(16+24+24+24) in_channel을 88로 설정, 

       self.incept1 = InceptionModule(in_channels=10) 
      # 위에서 설정한 InceptionModule 클래스에 in_channels를 10으로 설정하여 실행
       self.incept2 = InceptionModule(in_channels=20) 
      # InceptionModule 클래스에 in_channels를 20으로 설정하여 실행

       self.max_pool = nn.MaxPool2d(2)
      # max_pooling의 기본 설정값인 2x2로 연산한 activation map을 max_pooling 
       self.fc = nn.Linear(1408,10)
      # 전체 프로그램을 실행하면 나오는 에러를 통해서 최종 연산의 차원인 1408을 확인한 후 대입하여 fully connect의 input으로 넘겨줌

     def forward(self,x):
      in_size = x.size(0) 
      # size(0)을 하면 (n, 28*28)중 n을 리턴함 
      x = F.relu(self.max_pool(self.conv1(x)))
      # 위에서 정의한 conv1에 x를 대입하고 max_pooling을 통해 특징을 뽑아낸 데이터를 ReLu를 통해 activation
      # Sigmoid 함수의 경우 결과가 0~1 사이에서 값이 머무름.
      # 때문에 neural net의 hidden layer 수가 많을 때, 역전파 과정에서 weight값이 원래의 입력에 미치는 영향이 거의 미미해지는 vanishing gradients현상이 발생
      # 때문에 학습 layer의 수가 많을 때는 Sigmoid보다 ReLu 함수가 비교적 효율적임

      x = self.incept1(x)
      # conv1을 ReLu를 통해 activation한 결과를 위에서 정의한 self.incept1, 즉 Inception Module에 대입 
      x = F.relu(self.max_pool(self.conv2(x)))
      # 위에서 정의한 self.conv2에 앞서 연산한 x를 대입한 후 __init__에서 정의한 대로 2x2 크기로 Max Pooling 실행하여 x에 저장
      x = self.incept2(x) 
      # 마지막으로 self.incept2()에 위에서 과정을 거친 x 대입
      x = x.view(in_size,-1)
      # in_channel의 값만 그대로 두고 나머지 값들은 -1로 펴버림
      # batch_size * channel * width * height였다면
      # batch_size, (channel * width * height)의 형태로
      x = self.fc(x)
      # conv2d 과정과 max_pooling을 마친 1408개의 cell들에 대하여 fully connected 실행
      return F.log_softmax(x)
      # 연산된 값들을 softmax activation을 통하여 출력

model = MainNet().to(device)
# 연산에 GPU를 사용하기 위한 과정
optimizer = optim.SGD(model.parameters(),lr=0.01,momentum=0.5)
# 스토케스틱 경사 하강법을 사용할 때 파라미터 값에 꼭 사용하는 model의 parameters()를 입력해줘야 함
# 학습률을 0.01로 설정하여 train 과정의 역전파에서 사용.
# 수정할 때의 momentum은 0.5로 설정
criterion = nn.NLLLoss()
# forward의 return값으로 연산을 마친 fully connected layer에 softmax 함수를 적용했으므로 NLLLoss()를 통해 라벨 분류 마무리.

# train 과정
def train(epoch): 
  model.train() 
  for batch_idx, (data, target) in enumerate(train_loader):
  # 프로그램 처음에 설정했던 train_loader에서 데이터를 가져옴
     data = data.to(device) 
     target = target.to(device) 
     
     output = model(data) 
     optimizer.zero_grad() 
     #네트워크 시작할 때 네트워크의 각 파라미터의 gradient를 0으로 초기화해줌
     loss = criterion(output, target) 
     loss.backward()
     # 계산된 loss값, 즉 원래의 라벨과 예상값의 차이에서 발생하는 loss들에 대한 역전파 
     optimizer.step() 
     # 역전파를 통해 얻은 gradient를 optimzer.step()을 통해 업데이트
     if batch_idx % 50 == 0:
        print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format( epoch, batch_idx * len(data), len(train_loader.dataset), 100. * batch_idx / len(train_loader), loss.data.item())) 

# test 과정
def test(): 
  model.eval() 
  test_loss = 0 
  correct = 0 
  for data, target in test_loader:
     data = data.to(device) 
     target = target.to(device) 
     output = model(data)
     test_loss += criterion(output, target).data.item()
     # get the index of the max log-probability 
     pred = output.data.max(1, keepdim=True)[1] 
     correct += pred.eq(target.data.view_as(pred)).cpu().sum() 
     
     test_loss /= len(test_loader.dataset)/batch_size 
     print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format( test_loss, correct, len(test_loader.dataset), 100. * correct / len(test_loader.dataset)))

for epoch in range(1, 10):
# epoch는 총 train과 test를 몇 번 실행할지 결정
   train(epoch) 
   test()
# 9번의 train 이후의 test 값을 보게 되면 정확도가 98%에 이르는 걸 확인할 수 있다.
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:65: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.301080
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 2.301867
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 2.249562
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 1.965307
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.872830
# Train Epoch: 1 [16000/60000 (27%)]	Loss: 0.484028
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.658978
# Train Epoch: 1 [22400/60000 (37%)]	Loss: 0.468170
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.321620
# Train Epoch: 1 [28800/60000 (48%)]	Loss: 0.650340
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.412608
# Train Epoch: 1 [35200/60000 (59%)]	Loss: 0.338902
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.153474
# Train Epoch: 1 [41600/60000 (69%)]	Loss: 0.135509
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.319458
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.109290
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.157062
# Train Epoch: 1 [54400/60000 (91%)]	Loss: 0.108825
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.238749
#
# Test set: Average loss: 0.0007, Accuracy: 62/10000 (0%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 125/10000 (1%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 188/10000 (1%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 248/10000 (2%)
#
#
# Test set: Average loss: 0.0017, Accuracy: 308/10000 (3%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 367/10000 (3%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 427/10000 (4%)
#
#
# Test set: Average loss: 0.0019, Accuracy: 481/10000 (4%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 542/10000 (5%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 600/10000 (6%)
#
#
# Test set: Average loss: 0.0016, Accuracy: 660/10000 (6%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 719/10000 (7%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 782/10000 (7%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 844/10000 (8%)
#
#
# Test set: Average loss: 0.0016, Accuracy: 900/10000 (9%)
#
#
# Test set: Average loss: 0.0017, Accuracy: 961/10000 (9%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 1021/10000 (10%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 1081/10000 (10%)
#
#
# Test set: Average loss: 0.0015, Accuracy: 1138/10000 (11%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 1196/10000 (11%)
#
#
# Test set: Average loss: 0.0024, Accuracy: 1254/10000 (12%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 1316/10000 (13%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 1376/10000 (13%)
#
#
# Test set: Average loss: 0.0018, Accuracy: 1437/10000 (14%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 1496/10000 (14%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 1556/10000 (15%)
#
#
# Test set: Average loss: 0.0024, Accuracy: 1616/10000 (16%)
#
#
# Test set: Average loss: 0.0020, Accuracy: 1674/10000 (16%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 1735/10000 (17%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 1795/10000 (17%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 1853/10000 (18%)
#
#
# Test set: Average loss: 0.0023, Accuracy: 1913/10000 (19%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 1973/10000 (19%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 2032/10000 (20%)
#
#
# Test set: Average loss: 0.0029, Accuracy: 2090/10000 (20%)
#
#
# Test set: Average loss: 0.0018, Accuracy: 2150/10000 (21%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 2209/10000 (22%)
#
#
# Test set: Average loss: 0.0019, Accuracy: 2264/10000 (22%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 2326/10000 (23%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 2387/10000 (23%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 2447/10000 (24%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 2507/10000 (25%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 2567/10000 (25%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 2627/10000 (26%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 2688/10000 (26%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 2747/10000 (27%)
#
#
# Test set: Average loss: 0.0019, Accuracy: 2804/10000 (28%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 2867/10000 (28%)
#
#
# Test set: Average loss: 0.0018, Accuracy: 2926/10000 (29%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 2989/10000 (29%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 3050/10000 (30%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 3112/10000 (31%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 3170/10000 (31%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 3232/10000 (32%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 3294/10000 (32%)
#
#
# Test set: Average loss: 0.0018, Accuracy: 3354/10000 (33%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 3415/10000 (34%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 3477/10000 (34%)
#
#
# Test set: Average loss: 0.0024, Accuracy: 3534/10000 (35%)
#
#
# Test set: Average loss: 0.0026, Accuracy: 3591/10000 (35%)
#
#
# Test set: Average loss: 0.0025, Accuracy: 3645/10000 (36%)
#
#
# Test set: Average loss: 0.0021, Accuracy: 3703/10000 (37%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 3764/10000 (37%)
#
#
# Test set: Average loss: 0.0019, Accuracy: 3822/10000 (38%)
#
#
# Test set: Average loss: 0.0017, Accuracy: 3879/10000 (38%)
#
#
# Test set: Average loss: 0.0019, Accuracy: 3937/10000 (39%)
#
#
# Test set: Average loss: 0.0015, Accuracy: 3994/10000 (39%)
#
#
# Test set: Average loss: 0.0022, Accuracy: 4052/10000 (40%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 4114/10000 (41%)
#
#
# Test set: Average loss: 0.0017, Accuracy: 4171/10000 (41%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 4230/10000 (42%)
#
#
# Test set: Average loss: 0.0020, Accuracy: 4289/10000 (42%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 4350/10000 (43%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 4411/10000 (44%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 4471/10000 (44%)
#
#
# Test set: Average loss: 0.0019, Accuracy: 4529/10000 (45%)
#
#
# Test set: Average loss: 0.0015, Accuracy: 4589/10000 (45%)
#
#
# Test set: Average loss: 0.0017, Accuracy: 4648/10000 (46%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 4712/10000 (47%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 4772/10000 (47%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 4831/10000 (48%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 4895/10000 (48%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 4955/10000 (49%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 5018/10000 (50%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 5082/10000 (50%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 5145/10000 (51%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 5209/10000 (52%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 5271/10000 (52%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 5333/10000 (53%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 5394/10000 (53%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 5458/10000 (54%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 5519/10000 (55%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 5581/10000 (55%)
#
#
# Test set: Average loss: 0.0016, Accuracy: 5639/10000 (56%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 5698/10000 (56%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 5760/10000 (57%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 5822/10000 (58%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5886/10000 (58%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5949/10000 (59%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 6012/10000 (60%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 6075/10000 (60%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 6136/10000 (61%)
#
#
# Test set: Average loss: 0.0017, Accuracy: 6195/10000 (61%)
#
#
# Test set: Average loss: 0.0028, Accuracy: 6249/10000 (62%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 6313/10000 (63%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 6372/10000 (63%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 6432/10000 (64%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 6495/10000 (64%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 6557/10000 (65%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6621/10000 (66%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 6685/10000 (66%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 6747/10000 (67%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 6810/10000 (68%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 6872/10000 (68%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6936/10000 (69%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7000/10000 (70%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 7060/10000 (70%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 7121/10000 (71%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 7183/10000 (71%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 7246/10000 (72%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 7309/10000 (73%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7373/10000 (73%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 7434/10000 (74%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 7496/10000 (74%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7560/10000 (75%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 7623/10000 (76%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 7683/10000 (76%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 7746/10000 (77%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 7808/10000 (78%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 7871/10000 (78%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 7934/10000 (79%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 7997/10000 (79%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 8060/10000 (80%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 8123/10000 (81%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 8186/10000 (81%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8250/10000 (82%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8314/10000 (83%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8378/10000 (83%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 8441/10000 (84%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8505/10000 (85%)
#
#
# Test set: Average loss: 0.0016, Accuracy: 8565/10000 (85%)
#
#
# Test set: Average loss: 0.0016, Accuracy: 8627/10000 (86%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 8690/10000 (86%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 8753/10000 (87%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 8817/10000 (88%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 8880/10000 (88%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8944/10000 (89%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 9006/10000 (90%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 9068/10000 (90%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 9130/10000 (91%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 9191/10000 (91%)
#
#
# Test set: Average loss: 0.0017, Accuracy: 9250/10000 (92%)
#
#
# Test set: Average loss: 0.0033, Accuracy: 9303/10000 (93%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 9362/10000 (93%)
#
#
# Test set: Average loss: 0.0023, Accuracy: 9418/10000 (94%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 9478/10000 (94%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 9494/10000 (94%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.249171
# Train Epoch: 2 [3200/60000 (5%)]	Loss: 0.108500
# Train Epoch: 2 [6400/60000 (11%)]	Loss: 0.166259
# Train Epoch: 2 [9600/60000 (16%)]	Loss: 0.155254
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.288792
# Train Epoch: 2 [16000/60000 (27%)]	Loss: 0.121176
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 0.110024
# Train Epoch: 2 [22400/60000 (37%)]	Loss: 0.113386
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.115562
# Train Epoch: 2 [28800/60000 (48%)]	Loss: 0.056007
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 0.039026
# Train Epoch: 2 [35200/60000 (59%)]	Loss: 0.167503
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.082156
# Train Epoch: 2 [41600/60000 (69%)]	Loss: 0.117081
# Train Epoch: 2 [44800/60000 (75%)]	Loss: 0.209309
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.097864
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.098182
# Train Epoch: 2 [54400/60000 (91%)]	Loss: 0.235086
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.166668
#
# Test set: Average loss: 0.0003, Accuracy: 63/10000 (0%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 127/10000 (1%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 191/10000 (1%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 252/10000 (2%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 314/10000 (3%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 375/10000 (3%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 437/10000 (4%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 498/10000 (4%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 561/10000 (5%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 622/10000 (6%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 684/10000 (6%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 746/10000 (7%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 809/10000 (8%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 872/10000 (8%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 933/10000 (9%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 994/10000 (9%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 1056/10000 (10%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 1116/10000 (11%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 1177/10000 (11%)
#
#
# Test set: Average loss: 0.0020, Accuracy: 1237/10000 (12%)
#
#
# Test set: Average loss: 0.0018, Accuracy: 1297/10000 (12%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 1360/10000 (13%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 1421/10000 (14%)
#
#
# Test set: Average loss: 0.0015, Accuracy: 1482/10000 (14%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 1544/10000 (15%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 1606/10000 (16%)
#
#
# Test set: Average loss: 0.0016, Accuracy: 1666/10000 (16%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 1728/10000 (17%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 1791/10000 (17%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 1851/10000 (18%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 1912/10000 (19%)
#
#
# Test set: Average loss: 0.0017, Accuracy: 1971/10000 (19%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 2033/10000 (20%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 2094/10000 (20%)
#
#
# Test set: Average loss: 0.0021, Accuracy: 2153/10000 (21%)
#
#
# Test set: Average loss: 0.0016, Accuracy: 2213/10000 (22%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 2275/10000 (22%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 2336/10000 (23%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 2399/10000 (23%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 2462/10000 (24%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 2524/10000 (25%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 2586/10000 (25%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 2648/10000 (26%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 2710/10000 (27%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 2771/10000 (27%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 2832/10000 (28%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 2891/10000 (28%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 2953/10000 (29%)
#
#
# Test set: Average loss: 0.0015, Accuracy: 3013/10000 (30%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 3076/10000 (30%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 3138/10000 (31%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 3202/10000 (32%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 3263/10000 (32%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 3325/10000 (33%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 3388/10000 (33%)
#
#
# Test set: Average loss: 0.0016, Accuracy: 3447/10000 (34%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 3508/10000 (35%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 3570/10000 (35%)
#
#
# Test set: Average loss: 0.0019, Accuracy: 3629/10000 (36%)
#
#
# Test set: Average loss: 0.0016, Accuracy: 3687/10000 (36%)
#
#
# Test set: Average loss: 0.0018, Accuracy: 3742/10000 (37%)
#
#
# Test set: Average loss: 0.0017, Accuracy: 3802/10000 (38%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 3864/10000 (38%)
#
#
# Test set: Average loss: 0.0017, Accuracy: 3924/10000 (39%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 3985/10000 (39%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 4046/10000 (40%)
#
#
# Test set: Average loss: 0.0015, Accuracy: 4104/10000 (41%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 4166/10000 (41%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 4228/10000 (42%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 4288/10000 (42%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 4349/10000 (43%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 4409/10000 (44%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 4472/10000 (44%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 4534/10000 (45%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 4597/10000 (45%)
#
#
# Test set: Average loss: 0.0015, Accuracy: 4656/10000 (46%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 4717/10000 (47%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 4779/10000 (47%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 4843/10000 (48%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 4905/10000 (49%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 4968/10000 (49%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 5031/10000 (50%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 5091/10000 (50%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5154/10000 (51%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5218/10000 (52%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 5281/10000 (52%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5345/10000 (53%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 5408/10000 (54%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 5471/10000 (54%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 5533/10000 (55%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5597/10000 (55%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 5658/10000 (56%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 5718/10000 (57%)
#
#
# Test set: Average loss: 0.0015, Accuracy: 5776/10000 (57%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 5838/10000 (58%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 5899/10000 (58%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 5960/10000 (59%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6024/10000 (60%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6088/10000 (60%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6152/10000 (61%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6216/10000 (62%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 6279/10000 (62%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 6340/10000 (63%)
#
#
# Test set: Average loss: 0.0023, Accuracy: 6397/10000 (63%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 6461/10000 (64%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 6522/10000 (65%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 6585/10000 (65%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 6649/10000 (66%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 6713/10000 (67%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6777/10000 (67%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6841/10000 (68%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6905/10000 (69%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 6969/10000 (69%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7033/10000 (70%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7097/10000 (70%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7160/10000 (71%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 7219/10000 (72%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 7281/10000 (72%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7345/10000 (73%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7408/10000 (74%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 7472/10000 (74%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7536/10000 (75%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 7595/10000 (75%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 7655/10000 (76%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 7718/10000 (77%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 7781/10000 (77%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 7843/10000 (78%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7907/10000 (79%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7971/10000 (79%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 8035/10000 (80%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 8098/10000 (80%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 8161/10000 (81%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 8224/10000 (82%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 8287/10000 (82%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8351/10000 (83%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8415/10000 (84%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8479/10000 (84%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8543/10000 (85%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8607/10000 (86%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8671/10000 (86%)
#
#
# Test set: Average loss: 0.0016, Accuracy: 8732/10000 (87%)
#
#
# Test set: Average loss: 0.0021, Accuracy: 8791/10000 (87%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 8855/10000 (88%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 8918/10000 (89%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8982/10000 (89%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9045/10000 (90%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9109/10000 (91%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 9173/10000 (91%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 9236/10000 (92%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 9299/10000 (92%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 9361/10000 (93%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 9421/10000 (94%)
#
#
# Test set: Average loss: 0.0019, Accuracy: 9480/10000 (94%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 9543/10000 (95%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 9602/10000 (96%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 9663/10000 (96%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9679/10000 (96%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.176044
# Train Epoch: 3 [3200/60000 (5%)]	Loss: 0.289513
# Train Epoch: 3 [6400/60000 (11%)]	Loss: 0.251466
# Train Epoch: 3 [9600/60000 (16%)]	Loss: 0.070234
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.067849
# Train Epoch: 3 [16000/60000 (27%)]	Loss: 0.131092
# Train Epoch: 3 [19200/60000 (32%)]	Loss: 0.139437
# Train Epoch: 3 [22400/60000 (37%)]	Loss: 0.093364
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.039816
# Train Epoch: 3 [28800/60000 (48%)]	Loss: 0.039545
# Train Epoch: 3 [32000/60000 (53%)]	Loss: 0.055115
# Train Epoch: 3 [35200/60000 (59%)]	Loss: 0.072366
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.045966
# Train Epoch: 3 [41600/60000 (69%)]	Loss: 0.127769
# Train Epoch: 3 [44800/60000 (75%)]	Loss: 0.129512
# Train Epoch: 3 [48000/60000 (80%)]	Loss: 0.156437
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.082309
# Train Epoch: 3 [54400/60000 (91%)]	Loss: 0.081155
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 0.047347
#
# Test set: Average loss: 0.0002, Accuracy: 63/10000 (0%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 127/10000 (1%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 191/10000 (1%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 253/10000 (2%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 315/10000 (3%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 375/10000 (3%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 437/10000 (4%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 499/10000 (4%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 562/10000 (5%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 624/10000 (6%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 687/10000 (6%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 748/10000 (7%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 811/10000 (8%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 873/10000 (8%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 932/10000 (9%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 993/10000 (9%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 1053/10000 (10%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 1114/10000 (11%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 1176/10000 (11%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 1237/10000 (12%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 1298/10000 (12%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 1359/10000 (13%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 1420/10000 (14%)
#
#
# Test set: Average loss: 0.0015, Accuracy: 1481/10000 (14%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 1542/10000 (15%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 1605/10000 (16%)
#
#
# Test set: Average loss: 0.0015, Accuracy: 1666/10000 (16%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 1727/10000 (17%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 1789/10000 (17%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 1851/10000 (18%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 1913/10000 (19%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 1974/10000 (19%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 2037/10000 (20%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 2099/10000 (20%)
#
#
# Test set: Average loss: 0.0019, Accuracy: 2158/10000 (21%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 2219/10000 (22%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 2280/10000 (22%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 2339/10000 (23%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 2401/10000 (24%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 2464/10000 (24%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 2526/10000 (25%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 2589/10000 (25%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 2651/10000 (26%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 2714/10000 (27%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 2776/10000 (27%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 2835/10000 (28%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 2895/10000 (28%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 2957/10000 (29%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 3018/10000 (30%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 3082/10000 (30%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 3145/10000 (31%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 3208/10000 (32%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 3270/10000 (32%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 3333/10000 (33%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 3395/10000 (33%)
#
#
# Test set: Average loss: 0.0018, Accuracy: 3455/10000 (34%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 3517/10000 (35%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 3580/10000 (35%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 3642/10000 (36%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 3703/10000 (37%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 3762/10000 (37%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 3820/10000 (38%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 3883/10000 (38%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 3943/10000 (39%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 4005/10000 (40%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 4066/10000 (40%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 4124/10000 (41%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 4185/10000 (41%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 4246/10000 (42%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 4306/10000 (43%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 4368/10000 (43%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 4429/10000 (44%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 4492/10000 (44%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 4555/10000 (45%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 4617/10000 (46%)
#
#
# Test set: Average loss: 0.0015, Accuracy: 4679/10000 (46%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 4740/10000 (47%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 4801/10000 (48%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 4864/10000 (48%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 4926/10000 (49%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 4989/10000 (49%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 5053/10000 (50%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 5115/10000 (51%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5179/10000 (51%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5243/10000 (52%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5307/10000 (53%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5371/10000 (53%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 5434/10000 (54%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 5497/10000 (54%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 5559/10000 (55%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5623/10000 (56%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 5684/10000 (56%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 5747/10000 (57%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 5806/10000 (58%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 5870/10000 (58%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5934/10000 (59%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 5996/10000 (59%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6060/10000 (60%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6124/10000 (61%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6188/10000 (61%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6252/10000 (62%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 6315/10000 (63%)
#
#
# Test set: Average loss: 0.0016, Accuracy: 6373/10000 (63%)
#
#
# Test set: Average loss: 0.0024, Accuracy: 6429/10000 (64%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 6493/10000 (64%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 6555/10000 (65%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 6618/10000 (66%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6682/10000 (66%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 6745/10000 (67%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6809/10000 (68%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 6873/10000 (68%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 6936/10000 (69%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7000/10000 (70%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7064/10000 (70%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7128/10000 (71%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7192/10000 (71%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 7252/10000 (72%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 7315/10000 (73%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 7378/10000 (73%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7442/10000 (74%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7505/10000 (75%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7569/10000 (75%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 7632/10000 (76%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7696/10000 (76%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7760/10000 (77%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7824/10000 (78%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 7887/10000 (78%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7951/10000 (79%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 8015/10000 (80%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 8078/10000 (80%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 8141/10000 (81%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 8204/10000 (82%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8268/10000 (82%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 8330/10000 (83%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8394/10000 (83%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8458/10000 (84%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8522/10000 (85%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8586/10000 (85%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8650/10000 (86%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8714/10000 (87%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 8775/10000 (87%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 8836/10000 (88%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8900/10000 (89%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8964/10000 (89%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9028/10000 (90%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 9091/10000 (90%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9155/10000 (91%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 9217/10000 (92%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9281/10000 (92%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 9343/10000 (93%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 9405/10000 (94%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 9467/10000 (94%)
#
#
# Test set: Average loss: 0.0019, Accuracy: 9527/10000 (95%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 9589/10000 (95%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 9650/10000 (96%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 9713/10000 (97%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 9729/10000 (97%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.088893
# Train Epoch: 4 [3200/60000 (5%)]	Loss: 0.165166
# Train Epoch: 4 [6400/60000 (11%)]	Loss: 0.030315
# Train Epoch: 4 [9600/60000 (16%)]	Loss: 0.035644
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.026608
# Train Epoch: 4 [16000/60000 (27%)]	Loss: 0.162175
# Train Epoch: 4 [19200/60000 (32%)]	Loss: 0.119739
# Train Epoch: 4 [22400/60000 (37%)]	Loss: 0.130597
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.154089
# Train Epoch: 4 [28800/60000 (48%)]	Loss: 0.087448
# Train Epoch: 4 [32000/60000 (53%)]	Loss: 0.163489
# Train Epoch: 4 [35200/60000 (59%)]	Loss: 0.119956
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.085504
# Train Epoch: 4 [41600/60000 (69%)]	Loss: 0.105590
# Train Epoch: 4 [44800/60000 (75%)]	Loss: 0.091770
# Train Epoch: 4 [48000/60000 (80%)]	Loss: 0.079223
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.072061
# Train Epoch: 4 [54400/60000 (91%)]	Loss: 0.043917
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 0.151627
#
# Test set: Average loss: 0.0001, Accuracy: 64/10000 (0%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 127/10000 (1%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 191/10000 (1%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 253/10000 (2%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 314/10000 (3%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 373/10000 (3%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 435/10000 (4%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 497/10000 (4%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 561/10000 (5%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 623/10000 (6%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 685/10000 (6%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 746/10000 (7%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 808/10000 (8%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 872/10000 (8%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 930/10000 (9%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 990/10000 (9%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 1052/10000 (10%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 1115/10000 (11%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 1175/10000 (11%)
#
#
# Test set: Average loss: 0.0015, Accuracy: 1237/10000 (12%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 1298/10000 (12%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 1361/10000 (13%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 1423/10000 (14%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 1482/10000 (14%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 1544/10000 (15%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 1606/10000 (16%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 1667/10000 (16%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 1729/10000 (17%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 1792/10000 (17%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 1852/10000 (18%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 1914/10000 (19%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 1974/10000 (19%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 2036/10000 (20%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 2097/10000 (20%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 2157/10000 (21%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 2218/10000 (22%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 2281/10000 (22%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 2342/10000 (23%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 2404/10000 (24%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 2468/10000 (24%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 2530/10000 (25%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 2593/10000 (25%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 2655/10000 (26%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 2717/10000 (27%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 2780/10000 (27%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 2842/10000 (28%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 2904/10000 (29%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 2966/10000 (29%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 3027/10000 (30%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 3090/10000 (30%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 3154/10000 (31%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 3218/10000 (32%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 3278/10000 (32%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 3340/10000 (33%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 3402/10000 (34%)
#
#
# Test set: Average loss: 0.0017, Accuracy: 3462/10000 (34%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 3525/10000 (35%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 3589/10000 (35%)
#
#
# Test set: Average loss: 0.0016, Accuracy: 3649/10000 (36%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 3708/10000 (37%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 3768/10000 (37%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 3829/10000 (38%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 3890/10000 (38%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 3950/10000 (39%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 4014/10000 (40%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 4077/10000 (40%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 4135/10000 (41%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 4198/10000 (41%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 4260/10000 (42%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 4323/10000 (43%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 4384/10000 (43%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 4444/10000 (44%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 4508/10000 (45%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 4572/10000 (45%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 4636/10000 (46%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 4696/10000 (46%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 4758/10000 (47%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 4821/10000 (48%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 4885/10000 (48%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 4949/10000 (49%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5013/10000 (50%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 5077/10000 (50%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 5140/10000 (51%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5204/10000 (52%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5268/10000 (52%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5331/10000 (53%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5395/10000 (53%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 5458/10000 (54%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 5520/10000 (55%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 5582/10000 (55%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5646/10000 (56%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 5706/10000 (57%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 5768/10000 (57%)
#
#
# Test set: Average loss: 0.0016, Accuracy: 5827/10000 (58%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 5890/10000 (58%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5954/10000 (59%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 6016/10000 (60%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6080/10000 (60%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6144/10000 (61%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6208/10000 (62%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6272/10000 (62%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 6335/10000 (63%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 6395/10000 (63%)
#
#
# Test set: Average loss: 0.0015, Accuracy: 6454/10000 (64%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6518/10000 (65%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 6580/10000 (65%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 6643/10000 (66%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6707/10000 (67%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6771/10000 (67%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6835/10000 (68%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6899/10000 (68%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6963/10000 (69%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7027/10000 (70%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7091/10000 (70%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7155/10000 (71%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7219/10000 (72%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 7282/10000 (72%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7346/10000 (73%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7410/10000 (74%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7473/10000 (74%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7536/10000 (75%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7600/10000 (76%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 7663/10000 (76%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 7725/10000 (77%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7789/10000 (77%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7853/10000 (78%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 7916/10000 (79%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7980/10000 (79%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8044/10000 (80%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8108/10000 (81%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8172/10000 (81%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 8235/10000 (82%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8299/10000 (82%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 8362/10000 (83%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8426/10000 (84%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8490/10000 (84%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8554/10000 (85%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8618/10000 (86%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8682/10000 (86%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8746/10000 (87%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 8807/10000 (88%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 8868/10000 (88%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8932/10000 (89%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8996/10000 (89%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 9060/10000 (90%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9124/10000 (91%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 9188/10000 (91%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 9251/10000 (92%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 9314/10000 (93%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 9378/10000 (93%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 9440/10000 (94%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 9500/10000 (95%)
#
#
# Test set: Average loss: 0.0017, Accuracy: 9559/10000 (95%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 9622/10000 (96%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 9683/10000 (96%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 9747/10000 (97%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 9763/10000 (97%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.058825
# Train Epoch: 5 [3200/60000 (5%)]	Loss: 0.007531
# Train Epoch: 5 [6400/60000 (11%)]	Loss: 0.021563
# Train Epoch: 5 [9600/60000 (16%)]	Loss: 0.042264
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.102413
# Train Epoch: 5 [16000/60000 (27%)]	Loss: 0.148454
# Train Epoch: 5 [19200/60000 (32%)]	Loss: 0.088147
# Train Epoch: 5 [22400/60000 (37%)]	Loss: 0.236112
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.121309
# Train Epoch: 5 [28800/60000 (48%)]	Loss: 0.017348
# Train Epoch: 5 [32000/60000 (53%)]	Loss: 0.034828
# Train Epoch: 5 [35200/60000 (59%)]	Loss: 0.105982
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.028529
# Train Epoch: 5 [41600/60000 (69%)]	Loss: 0.072991
# Train Epoch: 5 [44800/60000 (75%)]	Loss: 0.065139
# Train Epoch: 5 [48000/60000 (80%)]	Loss: 0.121122
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.039511
# Train Epoch: 5 [54400/60000 (91%)]	Loss: 0.127295
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 0.025369
#
# Test set: Average loss: 0.0002, Accuracy: 64/10000 (0%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 128/10000 (1%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 191/10000 (1%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 253/10000 (2%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 315/10000 (3%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 375/10000 (3%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 438/10000 (4%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 500/10000 (5%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 563/10000 (5%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 624/10000 (6%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 687/10000 (6%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 749/10000 (7%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 811/10000 (8%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 875/10000 (8%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 935/10000 (9%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 997/10000 (9%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 1059/10000 (10%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 1123/10000 (11%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 1184/10000 (11%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 1245/10000 (12%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 1306/10000 (13%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 1369/10000 (13%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 1432/10000 (14%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 1493/10000 (14%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 1556/10000 (15%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 1619/10000 (16%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 1680/10000 (16%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 1742/10000 (17%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 1806/10000 (18%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 1866/10000 (18%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 1929/10000 (19%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 1989/10000 (19%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 2051/10000 (20%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 2113/10000 (21%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 2174/10000 (21%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 2236/10000 (22%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 2299/10000 (22%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 2362/10000 (23%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 2425/10000 (24%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 2488/10000 (24%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 2552/10000 (25%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 2615/10000 (26%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 2677/10000 (26%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 2740/10000 (27%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 2804/10000 (28%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 2864/10000 (28%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 2924/10000 (29%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 2986/10000 (29%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 3048/10000 (30%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 3112/10000 (31%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 3175/10000 (31%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 3238/10000 (32%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 3301/10000 (33%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 3364/10000 (33%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 3427/10000 (34%)
#
#
# Test set: Average loss: 0.0018, Accuracy: 3488/10000 (34%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 3550/10000 (35%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 3613/10000 (36%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 3674/10000 (36%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 3734/10000 (37%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 3795/10000 (37%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 3855/10000 (38%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 3918/10000 (39%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 3978/10000 (39%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 4042/10000 (40%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 4105/10000 (41%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 4165/10000 (41%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 4228/10000 (42%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 4290/10000 (42%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 4354/10000 (43%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 4417/10000 (44%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 4477/10000 (44%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 4541/10000 (45%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 4605/10000 (46%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 4669/10000 (46%)
#
#
# Test set: Average loss: 0.0015, Accuracy: 4728/10000 (47%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 4790/10000 (47%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 4853/10000 (48%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 4916/10000 (49%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 4980/10000 (49%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 5043/10000 (50%)
#
#
# ...
#
#
# Test set: Average loss: 0.0002, Accuracy: 4244/10000 (42%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 4306/10000 (43%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 4370/10000 (43%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 4432/10000 (44%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 4494/10000 (44%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 4558/10000 (45%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 4622/10000 (46%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 4686/10000 (46%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 4746/10000 (47%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 4809/10000 (48%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 4872/10000 (48%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 4936/10000 (49%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5000/10000 (50%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5064/10000 (50%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 5127/10000 (51%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5191/10000 (51%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5255/10000 (52%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5319/10000 (53%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 5382/10000 (53%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5446/10000 (54%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 5509/10000 (55%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 5573/10000 (55%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 5635/10000 (56%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5699/10000 (56%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 5761/10000 (57%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5825/10000 (58%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 5885/10000 (58%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5949/10000 (59%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 6012/10000 (60%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 6073/10000 (60%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6137/10000 (61%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6201/10000 (62%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6265/10000 (62%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6329/10000 (63%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 6392/10000 (63%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 6451/10000 (64%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 6511/10000 (65%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6575/10000 (65%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 6638/10000 (66%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6702/10000 (67%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6766/10000 (67%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6830/10000 (68%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6894/10000 (68%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6958/10000 (69%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7022/10000 (70%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7086/10000 (70%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7150/10000 (71%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7214/10000 (72%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7278/10000 (72%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 7341/10000 (73%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7405/10000 (74%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7469/10000 (74%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7533/10000 (75%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7597/10000 (75%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7661/10000 (76%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 7721/10000 (77%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 7782/10000 (77%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7845/10000 (78%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7909/10000 (79%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7972/10000 (79%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8036/10000 (80%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8099/10000 (80%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 8162/10000 (81%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8226/10000 (82%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 8289/10000 (82%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8353/10000 (83%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8417/10000 (84%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8481/10000 (84%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8545/10000 (85%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8609/10000 (86%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8673/10000 (86%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8737/10000 (87%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8801/10000 (88%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 8862/10000 (88%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 8923/10000 (89%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8987/10000 (89%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 9051/10000 (90%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 9115/10000 (91%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9178/10000 (91%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 9242/10000 (92%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 9305/10000 (93%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9369/10000 (93%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 9432/10000 (94%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 9496/10000 (94%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 9558/10000 (95%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 9618/10000 (96%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9682/10000 (96%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 9744/10000 (97%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9808/10000 (98%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 9824/10000 (98%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.008541
# Train Epoch: 9 [3200/60000 (5%)]	Loss: 0.047365
# Train Epoch: 9 [6400/60000 (11%)]	Loss: 0.092696
# Train Epoch: 9 [9600/60000 (16%)]	Loss: 0.075808
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.020351
# Train Epoch: 9 [16000/60000 (27%)]	Loss: 0.053995
# Train Epoch: 9 [19200/60000 (32%)]	Loss: 0.027623
# Train Epoch: 9 [22400/60000 (37%)]	Loss: 0.138042
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.047602
# Train Epoch: 9 [28800/60000 (48%)]	Loss: 0.014986
# Train Epoch: 9 [32000/60000 (53%)]	Loss: 0.028157
# Train Epoch: 9 [35200/60000 (59%)]	Loss: 0.021493
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.028149
# Train Epoch: 9 [41600/60000 (69%)]	Loss: 0.008391
# Train Epoch: 9 [44800/60000 (75%)]	Loss: 0.066958
# Train Epoch: 9 [48000/60000 (80%)]	Loss: 0.046354
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.113140
# Train Epoch: 9 [54400/60000 (91%)]	Loss: 0.102825
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 0.014374
#
# Test set: Average loss: 0.0001, Accuracy: 63/10000 (0%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 127/10000 (1%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 191/10000 (1%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 253/10000 (2%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 316/10000 (3%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 378/10000 (3%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 441/10000 (4%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 502/10000 (5%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 566/10000 (5%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 627/10000 (6%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 689/10000 (6%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 751/10000 (7%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 814/10000 (8%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 877/10000 (8%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 939/10000 (9%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 1001/10000 (10%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 1063/10000 (10%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 1127/10000 (11%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 1187/10000 (11%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 1248/10000 (12%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 1308/10000 (13%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 1372/10000 (13%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 1435/10000 (14%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 1496/10000 (14%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 1559/10000 (15%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 1622/10000 (16%)
#
#
# Test set: Average loss: 0.0010, Accuracy: 1683/10000 (16%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 1746/10000 (17%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 1809/10000 (18%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 1871/10000 (18%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 1934/10000 (19%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 1996/10000 (19%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 2058/10000 (20%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 2119/10000 (21%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 2182/10000 (21%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 2243/10000 (22%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 2306/10000 (23%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 2368/10000 (23%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 2431/10000 (24%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 2495/10000 (24%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 2558/10000 (25%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 2621/10000 (26%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 2683/10000 (26%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 2747/10000 (27%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 2811/10000 (28%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 2871/10000 (28%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 2932/10000 (29%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 2994/10000 (29%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 3057/10000 (30%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 3121/10000 (31%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 3185/10000 (31%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 3248/10000 (32%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 3311/10000 (33%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 3374/10000 (33%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 3436/10000 (34%)
#
#
# Test set: Average loss: 0.0018, Accuracy: 3494/10000 (34%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 3557/10000 (35%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 3621/10000 (36%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 3682/10000 (36%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 3744/10000 (37%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 3805/10000 (38%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 3867/10000 (38%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 3929/10000 (39%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 3990/10000 (39%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 4054/10000 (40%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 4117/10000 (41%)
#
#
# Test set: Average loss: 0.0011, Accuracy: 4179/10000 (41%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 4241/10000 (42%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 4305/10000 (43%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 4368/10000 (43%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 4431/10000 (44%)
#
#
# Test set: Average loss: 0.0006, Accuracy: 4493/10000 (44%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 4556/10000 (45%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 4618/10000 (46%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 4681/10000 (46%)
#
#
# Test set: Average loss: 0.0014, Accuracy: 4741/10000 (47%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 4804/10000 (48%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 4866/10000 (48%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 4930/10000 (49%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 4993/10000 (49%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5057/10000 (50%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5121/10000 (51%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5185/10000 (51%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5249/10000 (52%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5313/10000 (53%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5377/10000 (53%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5441/10000 (54%)
#
#
# Test set: Average loss: 0.0004, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5568/10000 (55%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 5630/10000 (56%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5694/10000 (56%)
#
#
# Test set: Average loss: 0.0008, Accuracy: 5755/10000 (57%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 5819/10000 (58%)
#
#
# Test set: Average loss: 0.0009, Accuracy: 5879/10000 (58%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 5943/10000 (59%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6007/10000 (60%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6070/10000 (60%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6134/10000 (61%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6198/10000 (61%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6262/10000 (62%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6326/10000 (63%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 6389/10000 (63%)
#
#
# Test set: Average loss: 0.0017, Accuracy: 6447/10000 (64%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 6508/10000 (65%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6572/10000 (65%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 6636/10000 (66%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 6700/10000 (67%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6764/10000 (67%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6828/10000 (68%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6892/10000 (68%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 6956/10000 (69%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7020/10000 (70%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7084/10000 (70%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7148/10000 (71%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7212/10000 (72%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7276/10000 (72%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7340/10000 (73%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7404/10000 (74%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7468/10000 (74%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7532/10000 (75%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7596/10000 (75%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7660/10000 (76%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 7723/10000 (77%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7787/10000 (77%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 7851/10000 (78%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 7914/10000 (79%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 7977/10000 (79%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8041/10000 (80%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 8104/10000 (81%)
#
#
# Test set: Average loss: 0.0003, Accuracy: 8167/10000 (81%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8230/10000 (82%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 8293/10000 (82%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8357/10000 (83%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8421/10000 (84%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8485/10000 (84%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8549/10000 (85%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8613/10000 (86%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8677/10000 (86%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8741/10000 (87%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 8804/10000 (88%)
#
#
# Test set: Average loss: 0.0012, Accuracy: 8865/10000 (88%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 8927/10000 (89%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 8991/10000 (89%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 9055/10000 (90%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 9119/10000 (91%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9183/10000 (91%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 9247/10000 (92%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9311/10000 (93%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 9375/10000 (93%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 9439/10000 (94%)
#
#
# Test set: Average loss: 0.0002, Accuracy: 9502/10000 (95%)
#
#
# Test set: Average loss: 0.0007, Accuracy: 9563/10000 (95%)
#
#
# Test set: Average loss: 0.0013, Accuracy: 9623/10000 (96%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9687/10000 (96%)
#
#
# Test set: Average loss: 0.0005, Accuracy: 9748/10000 (97%)
#
#
# Test set: Average loss: 0.0001, Accuracy: 9812/10000 (98%)
#
#
# Test set: Average loss: 0.0000, Accuracy: 9828/10000 (98%)
