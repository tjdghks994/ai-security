# %%
# !ls
# Out:
# drive  sample_data

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir('drive/My Drive/ai-sec')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-b7965561232b> in <module>()
#       1 import os
# ----> 2 os.chdir('drive/My Drive/ai-sec')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/My Drive/ai-sec'

# %%
# !pwd
# Out:
# /content/drive/My Drive/ai-sec

# %%
# !git clone https://github.com/donggil-kim/ai-security.git
# Out:
# Cloning into 'ai-security'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 250 (delta 34), reused 25 (delta 9), pack-reused 183
# Receiving objects: 100% (250/250), 1.13 MiB | 1.22 MiB/s, done.
# Resolving deltas: 100% (87/87), done.

# %%
# !git clone https://github.com/GunhoChoi/PyTorch-FastCampus.git
# Out:
# Cloning into 'PyTorch-FastCampus'...
# remote: Enumerating objects: 1359, done.
# remote: Total 1359 (delta 0), reused 0 (delta 0), pack-reused 1359
# Receiving objects: 100% (1359/1359), 216.17 MiB | 12.68 MiB/s, done.
# Resolving deltas: 100% (464/464), done.
# Checking out files: 100% (540/540), done.
